# %%
import sys
sys.version
# Out:
# '3.8.2 | packaged by conda-forge | (default, Mar 23 2020, 17:55:48) \n[Clang 9.0.1 ]'

# %% [markdown]
# # Performance Validation
# [Performance of Pandas apply vs np.vectorize to create new column from existing columns](https://stackoverflow.com/questions/52673285/performance-of-pandas-apply-vs-np-vectorize-to-create-new-column-from-existing-c/52674448#52674448)

# %% [markdown]
# ## An Example

# %%
import pandas as pd
import geopandas
import geopy.distance
from math import radians, cos, sin, asin, sqrt
# geopy.distance.distance()

# %%
city1 = [{'City':"Buenos Aires","Country":"Argentina","Latitude":-34.58,"Longitude":-58.66},
           {'City':"Brasilia","Country":"Brazil","Latitude":-15.78 ,"Longitude":-70.66},
         {'City':"Santiago","Country":"Chile ","Latitude":-33.45 ,"Longitude":-70.66 }]
city2 =  [{'City':"Bogota","Country":"Colombia ","Latitude":4.60 ,"Longitude":-74.08},
           {'City':"Caracas","Country":"Venezuela","Latitude":10.48  ,"Longitude":-66.86}]
city1df = pd.DataFrame(city1)
city2df = pd.DataFrame(city2)

# %%
def dist1(p1, p2):
    lon1, lat1, lon2, lat2 = map(radians, [p1.x, p1.y, p2.x, p2.y])

    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 

    return c * 6373

def dist2(p1, p2):
    lon1, lat1, lon2, lat2 = map(radians, [p1[0], p1[1], p2[0], p2[1]])

    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 

    return c * 6373

def dist3(p1, p2):
    x = p1.y, p1.x
    y = p2.y, p2.x

    return geopy.distance.geodesic(x, y).km

def dist4(p1, p2):
    x = p1[1], p1[0]
    y = p2[1], p2[0]

    return geopy.distance.geodesic(x, y).km

# %%
gcity1df = geopandas.GeoDataFrame(
    city1df, 
    geometry=geopandas.points_from_xy(city1df.Longitude, city1df.Latitude)
)
gcity2df = geopandas.GeoDataFrame(
    city2df, 
    geometry=geopandas.points_from_xy(city2df.Longitude, city2df.Latitude)
)

# cross join geopandas
gcity1df['key'] = 1
gcity2df['key'] = 1
merged = gcity1df.merge(gcity2df, on='key')

# %%
merged['dist'] = list(map(dist1, merged['geometry_x'], merged['geometry_y']))
mapping = {
    'City_x': 'City',
    'Country_x': 'Country',
    'Latitude_x': 'Latitude',
    'Longitude_x': 'Longitude',
    'geometry_x': 'geometry',
    'City_y': 'Nearest',
    'dist': 'Distance'
}

nearest = merged.loc[merged.groupby(['City_x', 'Country_x'])['dist'].idxmin()]
nearest.rename(columns=mapping)[list(mapping.values())]
# Out:
#            City    Country  Latitude  Longitude                     geometry  \
# 2      Brasilia     Brazil    -15.78     -70.66  POINT (-70.66000 -15.78000)
# 0  Buenos Aires  Argentina    -34.58     -58.66  POINT (-58.66000 -34.58000)
# 4      Santiago     Chile     -33.45     -70.66  POINT (-70.66000 -33.45000)
#
#   Nearest     Distance
# 2  Bogota  2297.922808
# 0  Bogota  4648.004515
# 4  Bogota  4247.586882

# %% [markdown]
# ## Comparision

# %%
import warnings
import math
warnings.filterwarnings("ignore")

def index_where(num_a,min_a,step_s):
    num_b = math.ceil((num_a-min_a)/step_s)
    return str(num_b)

# %%
df = pd.read_csv("/Users/soda/Downloads/CodingFile/RAI_工程代码/che300/data_finall.csv",encoding='gbk')
df.columns = ['device_imei', 'gps_time', 'longitude', 'latitude', 'carid', 'date']
df.head(2)
# Out:
#        device_imei                 gps_time   longitude   latitude    carid  \
# 0  862368010117495  2019-10-01 07:52:02.962  112.036533  22.933911  粤WRM007
# 1  862368010117495  2019-10-01 07:52:13.937  112.036898  22.933698  粤WRM007
#
#          date
# 0  2019-10-01
# 1  2019-10-01

# %%
lat_min = df['latitude'].min()
lat_step = 0.0001

# %%
# %timeit df['loc_lat'] = df['latitude'].apply(lambda x:index_where(x,lat_min,lat_step))
# Out:
# 380 ms ± 6.22 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
def index_where(num_a,min_a=lat_min,step_s=lat_step):
    num_b = math.ceil((num_a-min_a)/step_s)
    return str(num_b)

# %%
# %timeit df['loc_lat'] = list(map(index_where,df['latitude']))
# Out:
# 339 ms ± 3.08 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Spatial Queries
# [r-tree spatial indexing with Python and geopandas](https://geoffboeing.com/2016/10/r-tree-spatial-index-python/)

# %%
import osmnx as ox, matplotlib.pyplot as plt, pandas as pd, geopandas as gpd
from descartes import PolygonPatch
from shapely.geometry import Point, Polygon, MultiPolygon
# %matplotlib inline

# %%
city = ox.gdf_from_place("成都市,中国",which_result=1)
ox.plot_shape(ox.project_gdf(city))
# Out:
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x15cf08970>)

# %% [markdown]
# *********

# %%
# get the boundary of some city
gdf = ox.gdf_from_place('Walnut Creek, California, USA')
gdf
# Out:
#                                             geometry  \
# 0  POLYGON ((-122.10015 37.91741, -122.09996 37.9...
#
#                                           place_name  bbox_north  bbox_south  \
# 0  Walnut Creek, Contra Costa County, California,...   37.946337   37.842468
#
#     bbox_east   bbox_west
# 0 -121.980607 -122.100149

# %%
# get the street network within this bounding box
west, south, east, north = gdf.unary_union.buffer(0.1).bounds
G = ox.graph_from_bbox(north, south, east, west, network_type='drive', retain_all=True)

# %%
G

# %%
# get lat-long points for each intersection
xy = [(data['x'], data['y']) for node, data in G.nodes(data=True)]
x, y = list(zip(*xy))

# %% [markdown]
# [cmap](https://matplotlib.org/gallery/color/named_colors.html#sphx-glr-gallery-color-named-colors-py)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
plt.scatter(x,y,alpha=0.1,marker='.',color='slategrey')

# %%
# turn the lat-long points into a geodataframe
gdf_nodes = gpd.GeoDataFrame(data={'x':x, 'y':y})
gdf_nodes.crs = gdf.crs
gdf_nodes.name = 'nodes'
gdf_nodes['geometry'] = gdf_nodes.apply(lambda row: Point((row['x'], row['y'])), axis=1)

# %%
gdf_nodes.head()
# Out:
#             x          y                     geometry
# 0 -122.027780  37.848172  POINT (-122.02778 37.84817)
# 1 -122.053837  37.884569  POINT (-122.05384 37.88457)
# 2 -122.061733  37.891569  POINT (-122.06173 37.89157)
# 3 -122.066630  37.913641  POINT (-122.06663 37.91364)
# 4 -122.061567  37.921702  POINT (-122.06157 37.92170)

# %%
# make the geometry a multipolygon if it's not already
geometry = gdf['geometry'].iloc[0]
if isinstance(geometry, Polygon):
    geometry = MultiPolygon([geometry])

# %%
# plot the city
west, south, east, north = gdf.unary_union.bounds
fig, ax = plt.subplots(figsize=(6,6))
for polygon in geometry:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=2)
    ax.add_patch(patch)
    
ax.set_xlim(west, east)
ax.set_ylim(south, north)
ax.axis('off')
plt.show()

# %%
# plot the intersections and the city
# west, south, east, north = gdf_nodes.unary_union.bounds
fig, ax = plt.subplots(figsize=(6,6))
for polygon in geometry:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=2)
    ax.add_patch(patch)

ax.scatter(x=gdf_nodes['x'], y=gdf_nodes['y'], s=1, c='m', linewidth=0, zorder=1)
    
# ax.set_xlim(west, east)
# ax.set_ylim(south, north)
ax.axis('off')
plt.show()

# %% [markdown]
# **geometry(bound)∩gdf_nodes(trajectory)**

# %%
sindex = gdf_nodes.sindex #街道的index
possible_matches_index = list(sindex.intersection(geometry.bounds))  #街道index和多边形边缘的交集
possible_matches = gdf_nodes.iloc[possible_matches_index] #（可能的）交集的索引
precise_matches = possible_matches[possible_matches.intersects(geometry)] #intersects和intersection方法

# %%
points_within_geometry = precise_matches 
points_outside_geometry = gdf_nodes[~gdf_nodes.isin(points_within_geometry)]

# %%
# plot the cut-up city
fig, ax = plt.subplots(figsize=(6,6))
for polygon in geometry:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=3)
    ax.add_patch(patch)

ax.scatter(x=points_outside_geometry['x'], y=points_outside_geometry['y'], s=1, c='r', linewidth=0, zorder=1)
ax.scatter(x=points_within_geometry['x'], y=points_within_geometry['y'], s=1, c='b', linewidth=0, zorder=2)
    
# ax.set_xlim(west, east)
# ax.set_ylim(south, north)
ax.axis('off')
plt.show()

# %% [markdown]
# # `Install Instruction`

# %% [markdown]
# `install on Virtual Enviroment`
#
# ```bash
# conda create -n geo_env
# # /Users/soda/anaconda3/envs/geo_env
# source deactivate
# conda activate geo_env
# conda config --env --add channels conda-forge
# conda config --env --set channel_priority strict
# conda install python=3 geopandas
# conda install python=3 osmnx
# conda install ipykernel
# sudo python -m ipykernel install --user --name=geo_env
# jupyter notebook
# ```
# 1. https://geopandas.readthedocs.io/en/latest/install.html
# 2. https://osmnx.readthedocs.io/en/stable/#installation
# 3. https://github.com/geopandas/geopandas/issues/1109
# 4. https://blog.csdn.net/qq_18298439/article/details/96278997
# 5. http://www.doc88.com/p-9902138592893.html
# 6. https://github.com/Anaconda-Platform/nb_conda_kernels
# 7. http://blog.itpub.net/69945560/viewspace-2669072/
# 8. https://geoffboeing.com/publications/osmnx-complex-street-networks/

# %%
# import numpy as np
# import pandas as pd
# data = pd.read_excel("/Users/soda/Downloads/CodingFile/hotel/chengdu.xlsx")
# data.head(2)

# %% [markdown]
# # Testing Example
# [Blog](https://blog.csdn.net/qq_28360131/article/details/81165168)

# %%
chengdu = ox.gdf_from_place("成都市,中国",which_result=1)

# %%
chengdu
# Out:
#                                             geometry  \
# 0  MULTIPOLYGON (((102.99027 30.78293, 102.99243 ...
#
#                      place_name  bbox_north  bbox_south   bbox_east  \
# 0  Chengdu City, Sichuan, China   31.437097   30.092046  104.891694
#
#     bbox_west
# 0  102.990271

# %%
geometry = chengdu['geometry'].iloc[0]
if isinstance(geometry, Polygon):
    geometry = MultiPolygon([geometry])

# %%
import pandas as pd
import numpy as np
data_path = "/Users/soda/Downloads/CodingFile/128960/868120220605684/"
df_1 = pd.read_csv(data_path+"/2020-04-06.csv")
df_2 = pd.read_csv(data_path+"/2020-04-02.csv")

# %%
print(df_1.shape,df_2.shape)
# Out:
# (1203, 7) (100, 5)

# %%
trajectory = pd.concat([df_1.loc[:,['longitude','latitude']],df_2.loc[:,['longitude','latitude']]])

# %%
gdf_traj = gpd.GeoDataFrame(data=trajectory)
gdf_traj.crs = chengdu.crs
gdf_traj.name = 'nodes'
gdf_traj['geometry'] = gdf_traj.apply(lambda row: Point((row['longitude'],row['latitude'])),axis=1)

# %%
sindex = gdf_traj.sindex
possible_matches_index = list(sindex.intersection(geometry.bounds))
possible_matches = gdf_traj.iloc[possible_matches_index]
precise_matches = possible_matches[possible_matches.intersects(geometry)]

# %%
# %time  gdf_traj.iloc[possible_matches_index]
# Out:
# CPU times: user 1.19 ms, sys: 69 µs, total: 1.26 ms
# Wall time: 1.2 ms
#      longitude   latitude                    geometry
# 99  104.100551  30.605113  POINT (104.10055 30.60511)
# 89  104.095867  30.605207  POINT (104.09587 30.60521)
# 88  104.095947  30.605367  POINT (104.09595 30.60537)
# 90  104.096160  30.605376  POINT (104.09616 30.60538)
# 2   104.097493  30.605436  POINT (104.09749 30.60544)
# ..         ...        ...                         ...
# 44  104.099262  30.611560  POINT (104.09926 30.61156)
# 61  104.099298  30.611849  POINT (104.09930 30.61185)
# 68  104.099164  30.612696  POINT (104.09916 30.61270)
# 47  104.099076  30.612878  POINT (104.09908 30.61288)
# 53  104.099102  30.613196  POINT (104.09910 30.61320)
#
# [100 rows x 3 columns]

# %% [markdown]
# # OSMnx Walkthrough
# 1. [OSMnx: Python for Street Networks](https://geoffboeing.com/2016/11/osmnx-python-street-networks/)
# 2. [Example repo](https://github.com/gboeing/osmnx-examples/blob/master/notebooks/00-osmnx-features-demo.ipynb)
# 3. [Geopandas](http://blog.itpub.net/31558017/viewspace-2284513/)
# [](https://blog.csdn.net/qq_28360131/article/details/81165168)

# %% [markdown]
# ## Get administrative place boundaries and shapefiles

# %%
city = ox.gdf_from_place('Berkeley, California')
ox.plot_shape(ox.project_gdf(city))
# Out:
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x173efec70>)

# %%
places = ox.gdf_from_places(['Botswana', 'Zambia', 'Zimbabwe'])
places = ox.project_gdf(places)
ox.plot_shape(ox.project_gdf(places))
# ox.save_gdf_shapefile(gdf=places, filename='places', folder='/Users/soda/Downloads/')
# Out:
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x171db4400>)

# %% [markdown]
# ## Download and construct street networks

# %% [markdown]
# ### street network from bounding box

# %%
G = ox.graph_from_bbox(37.79, 37.78, -122.41, -122.43, network_type='drive')
G_projected = ox.project_graph(G)
ox.plot_graph(G_projected)
# Out:
# (<Figure size 687.674x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x17254e610>)

# %% [markdown]
# ### street network from lat-long point

# %%
G = ox.graph_from_point((37.79, -122.41), distance=750, network_type='all')
ox.plot_graph(G)
# Out:
# (<Figure size 540.194x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x15d3961c0>)

# %% [markdown]
# ### street network from address

# %%
G = ox.graph_from_address('350 5th Ave, New York, New York', network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 568.567x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x15d38ab80>)

# %% [markdown]
# ### street network from polygon

# %%
G = ox.graph_from_polygon(mission_shape, network_type='drive')
ox.plot_graph(G)
# Out:
#                                             geometry  \
# 0  MULTIPOLYGON (((102.99027 30.78293, 102.99243 ...
#
#                      place_name  bbox_north  bbox_south   bbox_east  \
# 0  Chengdu City, Sichuan, China   31.437097   30.092046  104.891694
#
#     bbox_west
# 0  102.990271

# %% [markdown]
# ### street network from place name

# %%
# G = ox.graph_from_place('Los Angeles, California', network_type='drive')
# ox.plot_graph(G)

# %%
# places = ['Los Altos, California, USA',
#           {'city':'Los Altos Hills', 'state':'California'},
#           'Loyola, California']
# G = ox.graph_from_place(places, network_type='drive')
# ox.plot_graph(G)

# %% [markdown]
# ### street networks from all around the world

# %% [markdown]
# ## Correct and simplify network topology
